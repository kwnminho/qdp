# %%
# %matplotlib notebook
from QDP import qdp
import os.path
import numpy as np
from scipy.stats import poisson
import h5py
import matplotlib.pyplot as plt
from scipy.optimize import leastsq,curve_fit

# %%
#analysis_master_path='Y:/Rb/Analysis/' # Y:\ is network drive connected to Hexagon E:\Rb\

exp_id='2018_05_21_17_19_31_Microwave and 780 horizontall scan, tgap 800 ns'
data_master_path='D:/Data/' # D:\ is local SSD in the main experiment computer
exp_date="_".join(exp_id.split("_")[:3]) # Date folder name automatically generated from exp name.
exp_path=data_master_path+exp_date+'/'+exp_id+'/'
experiment_file='results.hdf5'
dp=exp_path
cuts = [[450],[450],[450]]

q = qdp.QDP(base_data_path=dp)
q.load_data_file(experiment_file)
for r in range(5):
    q.set_thresholds(cuts, roi=r)

# %%
q.experiments[0]['variable_list']
xlab = q.experiments[0]['variable_desc'][q.experiments[0]['variable_list'][0]]['description']
q.get_thresholds()
retention = q.apply_thresholds()
#np.squeeze(retention['retention'])

# %%
tbl_str = "ivar:\t{0:.2f}\tretention:{1:.3f} +- {2:.3f}"
for i in range(len(retention['retention'].flatten())):
    print(tbl_str.format(
        retention['ivar'].flatten()[i],
        retention['retention'].flatten()[i],
        retention['error'].flatten()[i]
    ))
# Out:
# ivar:	-300.00	retention:0.849 +- 0.028
# ivar:	-300.00	retention:0.864 +- 0.028
# ivar:	-300.00	retention:0.827 +- 0.028
# ivar:	-300.00	retention:0.463 +- 0.028
# ivar:	-300.00	retention:0.647 +- 0.028
# ivar:	-275.00	retention:0.871 +- 0.032
# ivar:	-275.00	retention:0.827 +- 0.032
# ivar:	-275.00	retention:0.653 +- 0.032
# ivar:	-275.00	retention:0.400 +- 0.032
# ivar:	-275.00	retention:0.623 +- 0.032
# ivar:	-250.00	retention:0.635 +- 0.028
# ivar:	-250.00	retention:0.850 +- 0.028
# ivar:	-250.00	retention:0.680 +- 0.028
# ivar:	-250.00	retention:0.407 +- 0.028
# ivar:	-250.00	retention:0.580 +- 0.028
# ivar:	-225.00	retention:0.649 +- 0.035
# ivar:	-225.00	retention:0.798 +- 0.035
# ivar:	-225.00	retention:0.697 +- 0.035
# ivar:	-225.00	retention:0.519 +- 0.035
# ivar:	-225.00	retention:0.603 +- 0.035
# ivar:	-200.00	retention:0.759 +- 0.037
# ivar:	-200.00	retention:0.730 +- 0.037
# ivar:	-200.00	retention:0.747 +- 0.037
# ivar:	-200.00	retention:0.528 +- 0.037
# ivar:	-200.00	retention:0.667 +- 0.037
# ivar:	-175.00	retention:0.769 +- 0.027
# ivar:	-175.00	retention:0.847 +- 0.027
# ivar:	-175.00	retention:0.645 +- 0.027
# ivar:	-175.00	retention:0.500 +- 0.027
# ivar:	-175.00	retention:0.769 +- 0.027
# ivar:	-150.00	retention:0.819 +- 0.034
# ivar:	-150.00	retention:0.672 +- 0.034
# ivar:	-150.00	retention:0.627 +- 0.034
# ivar:	-150.00	retention:0.431 +- 0.034
# ivar:	-150.00	retention:0.597 +- 0.034
# ivar:	-125.00	retention:0.792 +- 0.041
# ivar:	-125.00	retention:0.509 +- 0.041
# ivar:	-125.00	retention:0.573 +- 0.041
# ivar:	-125.00	retention:0.526 +- 0.041
# ivar:	-125.00	retention:0.647 +- 0.041
# ivar:	-100.00	retention:0.753 +- 0.043
# ivar:	-100.00	retention:0.505 +- 0.043
# ivar:	-100.00	retention:0.773 +- 0.043
# ivar:	-100.00	retention:0.382 +- 0.043
# ivar:	-100.00	retention:0.560 +- 0.043
# ivar:	-75.00	retention:0.670 +- 0.034
# ivar:	-75.00	retention:0.748 +- 0.034
# ivar:	-75.00	retention:0.680 +- 0.034
# ivar:	-75.00	retention:0.400 +- 0.034
# ivar:	-75.00	retention:0.547 +- 0.034
# ivar:	-50.00	retention:0.733 +- 0.031
# ivar:	-50.00	retention:0.792 +- 0.031
# ivar:	-50.00	retention:0.587 +- 0.031
# ivar:	-50.00	retention:0.500 +- 0.031
# ivar:	-50.00	retention:0.571 +- 0.031
# ivar:	-25.00	retention:0.731 +- 0.029
# ivar:	-25.00	retention:0.836 +- 0.029
# ivar:	-25.00	retention:0.467 +- 0.029
# ivar:	-25.00	retention:0.348 +- 0.029
# ivar:	-25.00	retention:0.594 +- 0.029
# ivar:	0.00	retention:0.758 +- 0.027
# ivar:	0.00	retention:0.865 +- 0.027
# ivar:	0.00	retention:0.267 +- 0.027
# ivar:	0.00	retention:0.269 +- 0.027
# ivar:	0.00	retention:0.660 +- 0.027
# ivar:	25.00	retention:0.698 +- 0.033
# ivar:	25.00	retention:0.765 +- 0.033
# ivar:	25.00	retention:0.447 +- 0.033
# ivar:	25.00	retention:0.467 +- 0.033
# ivar:	25.00	retention:0.618 +- 0.033
# ivar:	50.00	retention:0.712 +- 0.037
# ivar:	50.00	retention:0.778 +- 0.037
# ivar:	50.00	retention:0.632 +- 0.037
# ivar:	50.00	retention:0.519 +- 0.037
# ivar:	50.00	retention:0.756 +- 0.037
# ivar:	75.00	retention:0.724 +- 0.029
# ivar:	75.00	retention:0.869 +- 0.029
# ivar:	75.00	retention:0.693 +- 0.029
# ivar:	75.00	retention:0.452 +- 0.029
# ivar:	75.00	retention:0.580 +- 0.029
# ivar:	100.00	retention:0.747 +- 0.029
# ivar:	100.00	retention:0.848 +- 0.029
# ivar:	100.00	retention:0.667 +- 0.029
# ivar:	100.00	retention:0.474 +- 0.029
# ivar:	100.00	retention:0.436 +- 0.029

# %%
def sin(t,amp,freq,phase,offset):
    res = (amp*np.sin((2*np.pi*freq*t)+phase)) + offset
    return res 

def decaying_sin(t,tau,amp,freq,phase,offset):
    res = (amp*np.exp(-t/tau)*np.sin((2*np.pi*freq*t)+phase)) + offset
    return res 

def est_freq(ydata,tgap,tau,amp,freq,phase,offset): # Estimation of frequency change (from dy/df where y=sinusoidal fit)
    res=(ydata-decaying_sin(tau,tgap,amp,freq,phase,offset))/(amp*np.exp(-tgap/tau)*2*np.pi*tgap*np.cos(2*np.pi*freq*tgap+phase))
    return res

def gaussian(x,amp,x0,sigma,offset):
    res=(amp*np.exp((-(x-x0)**2)/(sigma**2)))+offset
    return res

# %%
colors=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728','#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
fig, ax = plt.subplots()
fit_guesses=[0.5,-0,50,0]
roi_dependency=[0,100,0,0]
fitted_parameters=[]
for roi in [1,2]:
    
    data = []
    reten = []
    err = []
    for e in range(len(np.squeeze(retention['ivar']))):
        data.append(np.squeeze(retention['ivar'])[e][roi])
        reten.append(np.squeeze(retention['retention'])[e][roi])
        err.append(np.squeeze(retention['error'])[e][roi])
    ax.errorbar(data,reten,yerr=err,label="ROI:{}".format(roi),fmt='o',color=colors[roi])
    guesses=np.add(fit_guesses,np.ones(len(fit_guesses))*(roi-2)*roi_dependency)
    print guesses
    fit = curve_fit(gaussian,data,reten,guesses)
    print "ROI:{}, amplitude : {}, location: {} , sigma:{}, offset:{}".format(roi,fit[0][0],fit[0][1],fit[0][2],fit[0][3])
    fitted_parameters.append(fit[0])
    #print fit[0]
    xarray=np.linspace(np.min(data),np.max(data),100)
    yfit=gaussian(xarray, np.float(fit[0][0]),np.float(fit[0][1]),np.float(fit[0][2]),np.float(fit[0][3]))
    plt.plot(xarray,yfit,color=colors[roi])

plt.show()
ax.set_title(exp_id)
ax.set_ylim(0, 1)
ax.set_xlabel(xlab)
ax.set_ylabel('retention')
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
# [   0.5 -100.    50.     0. ]
# ROI:1, amplitude : -0.360951786394, location: -114.790278038 , sigma:34.4745803139, offset:0.822555826945
# [  0.5   0.   50.    0. ]
# ROI:2, amplitude : -0.404357144958, location: -0.0909979893416 , sigma:35.8659154275, offset:0.687603580159

# %%
print q.experiments[0]['iterations'][0]['AAS_redside']
print q.experiments[0]['iterations'][0]['AAS_blueside']
# Out:
# {'sigma_y': 0.23042927641513455, 'sigma_x': 0.31815213353537913, 'error_x': -17.878092176828588, 'error_y': 1.1243327228843283, 'y': -1.1146672771156716, 'x': -97.708092176828586}
# {'sigma_y': 0.11799978510503216, 'sigma_x': 0.22414890937591472, 'error_x': -1.0093071128194868, 'error_y': -0.36435750623425633, 'y': 11.775642493765744, 'x': 5.9006928871805133}

# %%
colors=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728','#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
fig, ax = plt.subplots()
xdata = []
ydata = []
yerr = []
for e in range(len(np.squeeze(retention['ivar']))):
    xdata.append(np.squeeze(retention['ivar'])[e][2])
    ydata.append(q.experiments[0]['iterations'][e]['AAS_redside']['x'])
    yerr.append(q.experiments[0]['iterations'][e]['AAS_redside']['sigma_x'])
ax.errorbar(xdata,ydata,yerr=yerr,fmt='o',markersize=5)

plt.show()
ax.set_title(exp_id)
#ax.set_ylim(-10, 10)
ax.set_xlabel(xlab)
ax.set_ylabel('x')
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\Rb\AppData\Local\Enthought\Canopy\User\lib\site-packages\matplotlib\axes\_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
colors=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728','#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
fig, ax = plt.subplots()
xdata = []
ydata = []
yerr = []
for e in range(len(np.squeeze(retention['ivar']))):
    xdata.append(np.squeeze(retention['ivar'])[e][2])
    ydata.append(q.experiments[0]['iterations'][e]['AAS_redside']['y'])
    yerr.append(q.experiments[0]['iterations'][e]['AAS_redside']['sigma_y'])
ax.errorbar(xdata,ydata,yerr=yerr,fmt='o')

plt.show()
ax.set_title(exp_id)
#ax.set_ylim(0, 1)
ax.set_xlabel(xlab)
ax.set_ylabel('y')
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
