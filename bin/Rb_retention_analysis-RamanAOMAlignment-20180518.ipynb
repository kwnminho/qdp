# %%
# %matplotlib notebook
from QDP import qdp
import os.path
import numpy as np
from scipy.stats import poisson
import h5py
import matplotlib.pyplot as plt
from scipy.optimize import leastsq,curve_fit

# %%
#analysis_master_path='Y:/Rb/Analysis/' # Y:\ is network drive connected to Hexagon E:\Rb\

exp_id='2018_05_18_17_47_18_Microwave Ramsey with 780A, pointing AOM scan'
data_master_path='D:/Data/' # D:\ is local SSD in the main experiment computer
exp_date="_".join(exp_id.split("_")[:3]) # Date folder name automatically generated from exp name.
exp_path=data_master_path+exp_date+'/'+exp_id+'/'
experiment_file='results.hdf5'
dp=exp_path
cuts = [[450],[450],[450]]

q = qdp.QDP(base_data_path=dp)
q.load_data_file(experiment_file)
for r in range(5):
    q.set_thresholds(cuts, roi=r)

# %%
q.experiments[0]['variable_list']
xlab = q.experiments[0]['variable_desc'][q.experiments[0]['variable_list'][0]]['description']
q.get_thresholds()
retention = q.apply_thresholds()
#np.squeeze(retention['retention'])

# %%
tbl_str = "ivar:\t{0:.2f}\tretention:{1:.3f} +- {2:.3f}"
for i in range(len(retention['retention'].flatten())):
    print(tbl_str.format(
        retention['ivar'].flatten()[i],
        retention['retention'].flatten()[i],
        retention['error'].flatten()[i]
    ))
# Out:
# ivar:	150.00	retention:0.239 +- 0.039
# ivar:	150.00	retention:0.771 +- 0.039
# ivar:	150.00	retention:0.803 +- 0.039
# ivar:	150.00	retention:0.759 +- 0.039
# ivar:	150.00	retention:0.676 +- 0.039
# ivar:	151.00	retention:0.339 +- 0.036
# ivar:	151.00	retention:0.805 +- 0.036
# ivar:	151.00	retention:0.787 +- 0.036
# ivar:	151.00	retention:0.754 +- 0.036
# ivar:	151.00	retention:0.641 +- 0.036
# ivar:	152.00	retention:0.691 +- 0.035
# ivar:	152.00	retention:0.800 +- 0.035
# ivar:	152.00	retention:0.803 +- 0.035
# ivar:	152.00	retention:0.804 +- 0.035
# ivar:	152.00	retention:0.353 +- 0.035
# ivar:	153.00	retention:0.905 +- 0.043
# ivar:	153.00	retention:0.457 +- 0.043
# ivar:	153.00	retention:0.658 +- 0.043
# ivar:	153.00	retention:0.781 +- 0.043
# ivar:	153.00	retention:0.520 +- 0.043
# ivar:	154.00	retention:0.873 +- 0.029
# ivar:	154.00	retention:0.135 +- 0.029
# ivar:	154.00	retention:0.747 +- 0.029
# ivar:	154.00	retention:0.808 +- 0.029
# ivar:	154.00	retention:0.478 +- 0.029
# ivar:	155.00	retention:0.812 +- 0.023
# ivar:	155.00	retention:0.084 +- 0.023
# ivar:	155.00	retention:0.816 +- 0.023
# ivar:	155.00	retention:0.712 +- 0.023
# ivar:	155.00	retention:0.561 +- 0.023
# ivar:	156.00	retention:0.831 +- 0.041
# ivar:	156.00	retention:0.227 +- 0.041
# ivar:	156.00	retention:0.827 +- 0.041
# ivar:	156.00	retention:0.654 +- 0.041
# ivar:	156.00	retention:0.489 +- 0.041
# ivar:	157.00	retention:0.753 +- 0.043
# ivar:	157.00	retention:0.435 +- 0.043
# ivar:	157.00	retention:0.697 +- 0.043
# ivar:	157.00	retention:0.741 +- 0.043
# ivar:	157.00	retention:0.535 +- 0.043
# ivar:	158.00	retention:0.704 +- 0.048
# ivar:	158.00	retention:0.558 +- 0.048
# ivar:	158.00	retention:0.493 +- 0.048
# ivar:	158.00	retention:0.722 +- 0.048
# ivar:	158.00	retention:0.447 +- 0.048
# ivar:	159.00	retention:0.800 +- 0.045
# ivar:	159.00	retention:0.684 +- 0.045
# ivar:	159.00	retention:0.187 +- 0.045
# ivar:	159.00	retention:0.667 +- 0.045
# ivar:	159.00	retention:0.531 +- 0.045
# ivar:	160.00	retention:0.805 +- 0.037
# ivar:	160.00	retention:0.772 +- 0.037
# ivar:	160.00	retention:0.145 +- 0.037
# ivar:	160.00	retention:0.754 +- 0.037
# ivar:	160.00	retention:0.667 +- 0.037
# ivar:	161.00	retention:0.782 +- 0.031
# ivar:	161.00	retention:0.869 +- 0.031
# ivar:	161.00	retention:0.263 +- 0.031
# ivar:	161.00	retention:0.700 +- 0.031
# ivar:	161.00	retention:0.676 +- 0.031
# ivar:	162.00	retention:0.727 +- 0.034
# ivar:	162.00	retention:0.820 +- 0.034
# ivar:	162.00	retention:0.320 +- 0.034
# ivar:	162.00	retention:0.691 +- 0.034
# ivar:	162.00	retention:0.431 +- 0.034
# ivar:	163.00	retention:0.773 +- 0.037
# ivar:	163.00	retention:0.810 +- 0.037
# ivar:	163.00	retention:0.560 +- 0.037
# ivar:	163.00	retention:0.582 +- 0.037
# ivar:	163.00	retention:0.452 +- 0.037
# ivar:	164.00	retention:0.826 +- 0.030
# ivar:	164.00	retention:0.814 +- 0.030
# ivar:	164.00	retention:0.653 +- 0.030
# ivar:	164.00	retention:0.383 +- 0.030
# ivar:	164.00	retention:0.490 +- 0.030
# ivar:	165.00	retention:0.750 +- 0.037
# ivar:	165.00	retention:0.821 +- 0.037
# ivar:	165.00	retention:0.816 +- 0.037
# ivar:	165.00	retention:0.292 +- 0.037
# ivar:	165.00	retention:0.500 +- 0.037
# ivar:	166.00	retention:0.750 +- 0.038
# ivar:	166.00	retention:0.773 +- 0.038
# ivar:	166.00	retention:0.733 +- 0.038
# ivar:	166.00	retention:0.339 +- 0.038
# ivar:	166.00	retention:0.575 +- 0.038
# ivar:	167.00	retention:0.786 +- 0.042
# ivar:	167.00	retention:0.728 +- 0.042
# ivar:	167.00	retention:0.776 +- 0.042
# ivar:	167.00	retention:0.625 +- 0.042
# ivar:	167.00	retention:0.639 +- 0.042
# ivar:	168.00	retention:0.836 +- 0.033
# ivar:	168.00	retention:0.854 +- 0.033
# ivar:	168.00	retention:0.773 +- 0.033
# ivar:	168.00	retention:0.556 +- 0.033
# ivar:	168.00	retention:0.259 +- 0.033
# ivar:	169.00	retention:0.734 +- 0.032
# ivar:	169.00	retention:0.859 +- 0.032
# ivar:	169.00	retention:0.816 +- 0.032
# ivar:	169.00	retention:0.774 +- 0.032
# ivar:	169.00	retention:0.212 +- 0.032
# ivar:	170.00	retention:0.681 +- 0.033
# ivar:	170.00	retention:0.852 +- 0.033
# ivar:	170.00	retention:0.842 +- 0.033
# ivar:	170.00	retention:0.797 +- 0.033
# ivar:	170.00	retention:0.333 +- 0.033

# %%
def sin(t,amp,freq,phase,offset):
    res = (amp*np.sin((2*np.pi*freq*t)+phase)) + offset
    return res 

def decaying_sin(t,tau,amp,freq,phase,offset):
    res = (amp*np.exp(-t/tau)*np.sin((2*np.pi*freq*t)+phase)) + offset
    return res 

def est_freq(ydata,tgap,tau,amp,freq,phase,offset): # Estimation of frequency change (from dy/df where y=sinusoidal fit)
    res=(ydata-decaying_sin(tau,tgap,amp,freq,phase,offset))/(amp*np.exp(-tgap/tau)*2*np.pi*tgap*np.cos(2*np.pi*freq*tgap+phase))
    return res

def gaussian(x,amp,x0,sigma,offset):
    res=(amp*np.exp((-(x-x0)**2)/(sigma**2)))+offset
    return res

# %%
colors=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728','#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
fig, ax = plt.subplots()
fit_guesses=[0.5,160,2,0]
roi_dependency=[0,5,0,0]
fitted_parameters=[]
for roi in [1,2]:
    
    data = []
    reten = []
    err = []
    for e in range(len(np.squeeze(retention['ivar']))):
        data.append(np.squeeze(retention['ivar'])[e][roi])
        reten.append(np.squeeze(retention['retention'])[e][roi])
        err.append(np.squeeze(retention['error'])[e][roi])
    ax.errorbar(data,reten,yerr=err,label="ROI:{}".format(roi),fmt='o',color=colors[roi])
    guesses=np.add(fit_guesses,np.ones(len(fit_guesses))*(roi-2)*roi_dependency)
    fit = curve_fit(gaussian,data,reten,guesses)
    print "ROI:{}, amplitude : {}, location: {} , sigma:{}, offset:{}".format(roi,fit[0][0],fit[0][1],fit[0][2],fit[0][3])
    fitted_parameters.append(fit[0])
    #print fit[0]
    xarray=np.linspace(np.min(data),np.max(data),100)
    yfit=gaussian(xarray, np.float(fit[0][0]),np.float(fit[0][1]),np.float(fit[0][2]),np.float(fit[0][3]))
    plt.plot(xarray,yfit,color=colors[roi])

plt.show()
ax.set_title(exp_id)
ax.set_ylim(0, 1)
ax.set_xlabel(xlab)
ax.set_ylabel('retention')
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ROI:1, amplitude : -0.736844767262, location: 155.120685314 , sigma:2.4360863481, offset:0.814643809551
# ROI:2, amplitude : -0.656573878705, location: 160.278033143 , sigma:2.59991035152, offset:0.787611814573

# %%
(154.611+159.899)/2
# Out:
# 157.255

# %%
colors=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728','#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
fig, ax = plt.subplots()
xdata = []
ydata = []
yerr = []
for e in range(len(np.squeeze(retention['ivar']))):
    xdata.append(np.squeeze(retention['ivar'])[e][2])
    ydata.append(q.experiments[0]['iterations'][e]['AAS_redside']['x'])
    yerr.append(q.experiments[0]['iterations'][e]['AAS_redside']['sigma_x'])
ax.errorbar(xdata,ydata,yerr=yerr,fmt='o',markersize=5)

plt.show()
ax.set_title(exp_id)
#ax.set_ylim(-10, 10)
ax.set_xlabel(xlab)
ax.set_ylabel('x')
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\Rb\AppData\Local\Enthought\Canopy\User\lib\site-packages\matplotlib\axes\_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
colors=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728','#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
fig, ax = plt.subplots()
xdata = []
ydata = []
yerr = []
for e in range(len(np.squeeze(retention['ivar']))):
    xdata.append(np.squeeze(retention['ivar'])[e][2])
    ydata.append(q.experiments[0]['iterations'][e]['AAS_redside']['y'])
    yerr.append(q.experiments[0]['iterations'][e]['AAS_redside']['sigma_y'])
ax.errorbar(xdata,ydata,yerr=yerr,fmt='o')

plt.show()
ax.set_title(exp_id)
#ax.set_ylim(0, 1)
ax.set_xlabel(xlab)
ax.set_ylabel('x')
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
colors=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728','#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
fig, ax = plt.subplots()
xdata = []
ydata = []
yerr = []
for e in range(len(np.squeeze(retention['ivar']))):
    xdata.append(np.squeeze(retention['ivar'])[e][2])
    ydata.append(q.experiments[0]['iterations'][e]['AAS_blueside']['x'])
    yerr.append(q.experiments[0]['iterations'][e]['AAS_blueside']['sigma_x'])
ax.errorbar(xdata,ydata,yerr=yerr,fmt='o',markersize=5)

plt.show()
ax.set_title(exp_id)
#ax.set_ylim(-10, 10)
ax.set_xlabel(xlab)
ax.set_ylabel('x')
ax.legend()

colors=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728','#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
fig, ax = plt.subplots()
xdata = []
ydata = []
yerr = []
for e in range(len(np.squeeze(retention['ivar']))):
    xdata.append(np.squeeze(retention['ivar'])[e][2])
    ydata.append(q.experiments[0]['iterations'][e]['AAS_blueside']['y'])
    yerr.append(q.experiments[0]['iterations'][e]['AAS_blueside']['sigma_y'])
ax.errorbar(xdata,ydata,yerr=yerr,fmt='o',markersize=5)

plt.show()
ax.set_title(exp_id)
#ax.set_ylim(-10, 10)
ax.set_xlabel(xlab)
ax.set_ylabel('x')
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
